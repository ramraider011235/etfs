# %%
import datetime as dt
from os.path import exists
from pathlib import Path
import numpy as np
import pandas as pd
import yfinance as yf
from finviz import get_news
from yahooquery import Ticker
from newspaper import Article, Config
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from dateutil.relativedelta import relativedelta

import src.tools.functions as f0
import src.tools.lists as l0

pd.set_option('display.max_columns', None)
nltk.download("vader_lexicon")
nltk.download('punkt')
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0'
config = Config()
config.browser_user_agent = user_agent
config.request_timeout = 10
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/gdp/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /home/gdp/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
day1 = '2023-02-01'
month1 = str(day1)[:7]
year1 = str(day1)[:4]

bulk_data_file_1 = (f"/home/gdp/hot_box/etfs/data/bulk/{year1}/{month1}/{day1}/bulk_tickers.csv")
bulk_data_file_2 = (f"/home/gdp/hot_box/etfs/data/bulk/{year1}/{month1}/{day1}/core_selection_tickers.xlsx")
bulk_data_file_3 = (f"/home/gdp/hot_box/etfs/data/bulk/{year1}/{month1}/{day1}/dodds_etf_df.csv")
bulk_data_file_4 = (f"/home/gdp/hot_box/etfs/data/bulk/{year1}/{month1}/{day1}/etf_tickers.csv")
bulk_data_file_5 = (f"/home/gdp/hot_box/etfs/data/bulk/{year1}/{month1}/{day1}/Results.csv")

save_raw = Path(f"/home/gdp/hot_box/etfs/data/raw/{year1}/{month1}/{day1}/")
if not save_raw.exists():
    save_raw.mkdir(parents=True)

save_hist = Path(f"/home/gdp/hot_box/etfs/data/hist/{year1}/{month1}/{day1}/")
if not save_hist.exists():
    save_hist.mkdir(parents=True)    
    
sentiment = Path(f"/home/gdp/hot_box/etfs/data/sentiment/sentiment/{year1}/{month1}/{day1}/")
if not sentiment.exists():
    sentiment.mkdir(parents=True)   
    
single_news = Path(f"/home/gdp/hot_box/etfs/data/sentiment/single_news/{year1}/{month1}/{day1}/")
if not single_news.exists():
    single_news.mkdir(parents=True)
    
saveRec = Path(f"/home/gdp/hot_box/etfs/data/recommenders/{year1}/{month1}/{day1}/")
if not saveRec.exists():
    saveRec.mkdir(parents=True)

# %%
bulk_tickers_df = pd.DataFrame(pd.read_csv(bulk_data_file_1))
core_selection_tickers_df = pd.DataFrame(pd.read_excel(bulk_data_file_2))
dodds_etf_df_df = pd.DataFrame(pd.read_csv(bulk_data_file_3))
etf_tickers_df = pd.DataFrame(pd.read_csv(bulk_data_file_4))
chuck_tickers_df = pd.DataFrame(pd.read_csv(bulk_data_file_5))

etf_ticker_list = (
    # list(bulk_tickers_df['symbol']) + \
        # list(core_selection_tickers_df['AAA']) + \
            list(chuck_tickers_df['Symbol']) + \
                list(dodds_etf_df_df['ticker'])
                    # list(etf_tickers_df['symbol'])
    )

etf_ticker_list = list(set(etf_ticker_list))

len(etf_ticker_list)
# Out:
# 159

# %%
def get_history():
    hist = pd.DataFrame(
        yf.download(
            tickers=etf_ticker_list, 
            period='2y', 
            rounding=True, 
            group_by='tickers', 
            auto_adjust=True,
            actions=False,
            show_errors=True
        )
    )
    hist.to_pickle(save_hist / f"all_etf_history_data.pkl")

    for ticker in etf_ticker_list:
        try:    
            data = pd.DataFrame(hist[ticker])
            data.columns = [x.lower() for x in data.columns]
            data.index = pd.to_datetime(data.index)
            data.to_pickle(save_raw / f"{ticker}.pkl")    
        except Exception as e:
            etf_ticker_list.remove(ticker) 

    return etf_ticker_list

# %%
etf_ticker_list = get_history()
# Out:
# [*********************100%***********************]  159 of 159 completed

# %%
def technicals_minervini(rec_02_tickers):            
    exportList = pd.DataFrame(
        columns=[
            "ticker", 
            "rs_rating", 
            "returns_multiple", 
            "current_price", 
            "sma_50", 
            "sma_150", 
            "sma_200", 
            "sma_200_20", 
            "low_52_week", 
            "high_52_week"
        ]
    )    

    
    # Index Returns
    index_name = '^GSPC'
    if exists(save_raw / "sp500_index.pkl"):
        index_df = pd.DataFrame(pd.read_pickle(save_raw / "sp500_index.pkl"))
        index_df["pct_change"] = index_df["Close"].pct_change()
        index_return = (index_df["pct_change"] + 1).cumprod()[-1]

    elif not exists(save_raw / "sp500_index.pkl"):
        index_df = pd.DataFrame(yf.download(index_name, period='2y'))
        index_df.to_pickle(save_raw / "sp500_index.pkl")
        index_df["pct_change"] = index_df["Close"].pct_change()
        index_return = (index_df["pct_change"] + 1).cumprod()[-1]
        
        
    # Find top 50% performing stocks (relative to the S&P 500)
    returns_multiples = []
    for ticker in rec_02_tickers:

        # Calculating returns relative to the market (returns multiple)      
        try:
            df = pd.DataFrame(pd.read_pickle(save_raw / f"{ticker}.pkl"))
            df["pct_change"] = df["close"].pct_change()
            stock_return = (df["pct_change"] + 1).cumprod()[-1]
            returns_multiple = round((stock_return / index_return), 2)
            returns_multiples.extend([returns_multiple])

        except Exception:
            print(f"Bad Ticker: {ticker}")
         
         
    # Creating dataframe of only top 70%
    rs_df = pd.DataFrame(list(zip(rec_02_tickers, returns_multiples)),columns=["ticker", "returns_multiple"],)
    rs_df["rs_rating"] = rs_df["returns_multiple"].rank(pct=True) * 100
    rs_df = rs_df[rs_df["rs_rating"] >= rs_df["rs_rating"].quantile(0.3)]    
    
    
    # Checking Minervini conditions of top 60% of stocks in given list
    rs_stocks = list(rs_df["ticker"])
    
    for stock in rs_stocks:
        try:     
            df = pd.DataFrame(pd.read_pickle(save_raw / f"{stock}.pkl")).dropna()
            sma = [50, 150, 200]

            for x in sma:
                df["SMA_" + str(x)] = round(df["close"].rolling(window=x).mean(), 2)

            # Storing required values
            currentClose = df["close"].iloc[-1]
            MA_50 = df["SMA_50"].iloc[-1]
            MA_150 = df["SMA_150"].iloc[-1]
            MA_200 = df["SMA_200"].iloc[-1]
            low_52_week = round(min(df["low"][-260:]), 2)
            high_52_week = round(max(df["high"][-260:]), 2)    
            RS_Rating = round(rs_df[rs_df["ticker"] == stock].rs_rating.tolist()[0], 2)
            Returns_multiple = round(rs_df[rs_df["ticker"] == stock].returns_multiple.tolist()[0], 2)
            
            try:
                MA_200_20 = df["SMA_200"][-20]
            except Exception:
                MA_200_20 = 0
                        
            condition_1 = currentClose >= MA_150 >= MA_200                                                            # Condition 1: Current Price > 150 SMA and > 200 SMA
            condition_2 = MA_150 >= MA_200                                                                            # Condition 2: 150 SMA and > 200 SMA
            condition_3 = MA_200 >= MA_200_20                                                                         # Condition 3: 200 SMA trending up for at least 1 month
            condition_4 = MA_50 >= MA_150 >= MA_200                                                                   # Condition 4: 50 SMA > 150 SMA and 50 SMA> 200 SMA
            condition_5 = currentClose >= MA_50                                                                       # Condition 5: Current Price > 50 SMA
            condition_6 = currentClose >= (1.3 * low_52_week)                                                         # Condition 6: Current Price is at least 30% above 52 week low
            condition_7 = currentClose >= (0.7 * high_52_week)                                                        # Condition 7: Current Price is within 30% of 52 week high

            # if (
            #     condition_1 & 
            #     # condition_2 & 
            #     condition_3 & 
            #     condition_4 &
            #     # condition_5 & 
            #     condition_6 & 
            #     condition_7
            #     ):                                                                                                      # If all conditions above are true, add Ticker to exportList 
            exportList = exportList.append(
                {
                    "ticker": stock,
                    "rs_rating": RS_Rating,
                    "returns_multiple": Returns_multiple,
                    "current_price": currentClose,
                    "sma_50": MA_50,
                    "sma_150": MA_150,
                    "sma_200": MA_200,
                    "sma_200_20": MA_200_20,
                    "low_52_week": low_52_week,
                    "high_52_week": high_52_week
                }, 
                ignore_index=True
            ).sort_values(by="rs_rating", ascending=False)
                    
        except Exception:
            print(f"Bad Ticker: {stock}")
            
    
    print("\n[2] MINERVINI ")
    print(f"   > PART-A:")
    exportList_A = exportList.drop_duplicates(subset="ticker")    
    part_a_len = len(exportList_A['ticker'])        
    print(f"     * Successful Stocks: [{part_a_len}]")
    
    
    print(f"   > PART-B:")
    exportList_B = exportList_A[exportList_A['rs_rating'] >= 30]
    exportList_B.to_pickle(saveRec / "recommender_02_return_dataFrame.pkl")
    part_b_len = len(exportList_B['ticker'])    
    print(f"     * Successful Stocks (rs_rating >= 69.0): [{part_b_len}]")    
    
    display(exportList_B.round(2))
    return exportList_B.round(2)

# %%
data_2 = technicals_minervini(etf_ticker_list)
# Out:
# [2] MINERVINI
#    > PART-A:
#      * Successful Stocks: [111]
#    > PART-B:
#      * Successful Stocks (rs_rating >= 69.0): [111]
#     ticker  rs_rating  returns_multiple  current_price  sma_50  sma_150  \
# 0     NRGU     100.00              5.88         442.90  508.01   465.73
# 1      DIG      99.37              3.85          40.59   43.05    38.93
# 2      ERX      98.74              3.71          63.61   67.10    60.17
# 3     GUSH      98.11              2.72         141.91  153.02   156.32
# 4      PXE      97.48              2.34          28.97   30.30    29.99
# ..     ...        ...               ...            ...     ...      ...
# 105    PIO      32.70              0.94          36.61   34.02    32.42
# 106   EIPX      32.70              0.94          20.43   20.22      NaN
# 107   JHMI      32.70              0.94          45.29   45.37    46.65
# 108    JXI      31.13              0.93          60.69   60.64    60.03
# 109   EBLU      31.13              0.93          41.11   38.37    37.05
#
#      sma_200  sma_200_20  low_52_week  high_52_week
# 0     478.63      470.57       198.58        797.00
# 1      38.75       38.03        21.66         50.45
# 2      60.38       59.26        34.20         80.27
# 3     162.11      164.31        84.50        257.76
# 4      30.05       29.87        19.97         36.69
# ..       ...         ...          ...           ...
# 105    32.59       32.71        27.82         39.14
# 106      NaN         NaN        19.46         20.84
# 107    47.70       48.66        41.94         56.51
# 108    60.74       61.22        51.01         67.69
# 109    37.21       37.43        32.00         46.24
#
# [111 rows x 10 columns]

# %%
from os.path import exists
from pathlib import Path
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newspaper import Article, Config
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

pd.set_option('display.max_columns', None)
nltk.download("vader_lexicon")
nltk.download("punkt")

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0'
config = Config()
config.browser_user_agent = user_agent
config.request_timeout = 10



day1 = day1
month1 = str(day1)[:7]
year1 = str(day1)[:4]
saveRec = Path(f"/home/gdp/hot_box/etfs/data/recommenders/{year1}/{month1}/{day1}/")
sentiment = Path(f"/home/gdp/hot_box/etfs/data/sentiment/sentiment/{year1}/{month1}/{day1}/")
single_news = Path(f"/home/gdp/hot_box/etfs/data/sentiment/single_news/{year1}/{month1}/{day1}/")   
if not sentiment.exists():
    sentiment.mkdir(parents=True)          
if not single_news.exists():
    single_news.mkdir(parents=True)       

data_2 = pd.read_pickle(saveRec / "recommender_02_return_dataFrame.pkl")
stocks_list = list(data_2['ticker'])
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/gdp/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /home/gdp/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def sentiment_1(stocks, parsed_news=[], new_stock_list=[], pull_list=[], bad_stocks=[], news_tables={}, n=10):
        

    def finviz_pull(tickers, c=0.0):
        for ticker in tickers:          
            c += 1
            try:
                url = 'https://finviz.com/quote.ashx?t=' + ticker
                req = Request(url=url,headers={'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0'}) 
                resp = urlopen(req)    
                html = BeautifulSoup(resp, features="lxml")
                news_table = html.find(id='news-table')
                news_tables[ticker] = news_table
                new_stock_list.append(ticker)
                print(f"({c}) [{ticker}] - DATA SOURCED")
            except Exception:
                bad_stocks.append(ticker)

        if exists(single_news / f"sentiment_all_stock_news.pkl"):
            parsed_news_df = pd.read_pickle(single_news / f"sentiment_all_stock_news.pkl")
            return parsed_news_df
            
        else:
            for file_name, news_table in news_tables.items():
                try:
                    rows = news_table.findAll("tr")
                    rows = rows[:n]
                    for row in rows:
                        cols = row.findAll("td")
                        try:
                            ticker = file_name.split('_')[0]
                            date = cols[0].text.split()[0]
                            title = cols[1].get_text()
                            link = cols[1].a['href']
                            source = link.split("/")[2]          
                            if source == "feedproxy.google.com":
                                source = link.split("/")[4]
                            info_dict = {
                                "Ticker": ticker,
                                "Date": date, 
                                "Title": title, 
                                "Source": source, 
                                "Link": link
                                }
                            parsed_news.append(info_dict)
                        except Exception:
                            pass
                except Exception as e:
                    print(e)
                    pass
                    
            parsed_news_df = pd.DataFrame(parsed_news)
            parsed_news_df.columns = [x.lower() for x in parsed_news_df.columns]
            parsed_news_df['date'] = pd.to_datetime(parsed_news_df['date'])
            # parsed_news_df = parsed_news_df[parsed_news_df['date'] >= pd.Timestamp('2022-01-01')]    
            parsed_news_df.to_pickle(single_news / f"sentiment_all_stock_news.pkl")
            for ticker in new_stock_list:
                if exists(single_news / f"df_single_news_{ticker}.pkl"):
                    pass
                else:            
                    stock_news_df = pd.DataFrame(parsed_news_df[parsed_news_df['ticker'] == ticker]).sort_values('date', ascending=False).iloc[:n]
                    stock_news_df.to_pickle(single_news / f"df_single_news_{ticker}.pkl")
                    print(f"{ticker} - COMPLETE - DATA SAVED")
            return parsed_news_df


    print(f"\nTotal Input Stocks: {len(stocks)} \n")
    pull_list = stocks
    parsed_news_df = finviz_pull(pull_list)
    return parsed_news_df

# %%
parsed_news_df = sentiment_1(stocks_list)
parsed_news_df
# Out:
# Total Input Stocks: 111
#
# (1.0) [NRGU] - DATA SOURCED
# (2.0) [DIG] - DATA SOURCED
# (3.0) [ERX] - DATA SOURCED
# (4.0) [GUSH] - DATA SOURCED
# (5.0) [PXE] - DATA SOURCED
# (6.0) [UCO] - DATA SOURCED
# (7.0) [FCG] - DATA SOURCED
# (8.0) [IEO] - DATA SOURCED
# (9.0) [FENY] - DATA SOURCED
# (10.0) [RYE] - DATA SOURCED
# (11.0) [XLE] - DATA SOURCED
# (12.0) [VDE] - DATA SOURCED
# (13.0) [IYE] - DATA SOURCED
# (14.0) [PXI] - DATA SOURCED
# (15.0) [FTXN] - DATA SOURCED
# (16.0) [UGA] - DATA SOURCED
# (17.0) [XOP] - DATA SOURCED
# (18.0) [FXN] - DATA SOURCED
# (19.0) [PSCE] - DATA SOURCED
# (20.0) [OIH] - DATA SOURCED
# (22.0) [BNO] - DATA SOURCED
# (23.0) [IEZ] - DATA SOURCED
# (24.0) [IXC] - DATA SOURCED
# (25.0) [USO] - DATA SOURCED
# (26.0) [FILL] - DATA SOURCED
# (27.0) [USL] - DATA SOURCED
# (28.0) [DBE] - DATA SOURCED
# (29.0) [XME] - DATA SOURCED
# (30.0) [AMZA] - DATA SOURCED
# (31.0) [IGE] - DATA SOURCED
# (32.0) [XES] - DATA SOURCED
# (33.0) [PXJ] - DATA SOURCED
# (34.0) [NANR] - DATA SOURCED
# (35.0) [URNM] - DATA SOURCED
# (36.0) [MLPA] - DATA SOURCED
# (37.0) [AMLP] - DATA SOURCED
# (39.0) [DBC] - DATA SOURCED
# (40.0) [DBO] - DATA SOURCED
# (41.0) [MLPX] - DATA SOURCED
# (42.0) [SLX] - DATA SOURCED
# (43.0) [UNL] - DATA SOURCED
# (44.0) [USAI] - DATA SOURCED
# (45.0) [EINC] - DATA SOURCED
# (46.0) [ENFR] - DATA SOURCED
# (47.0) [FXZ] - DATA SOURCED
# (48.0) [URA] - DATA SOURCED
# (49.0) [TPYP] - DATA SOURCED
# (50.0) [UMI] - DATA SOURCED
# (51.0) [GRES] - DATA SOURCED
# (52.0) [GUNR] - DATA SOURCED
# (53.0) [GNR] - DATA SOURCED
# (54.0) [DUSL] - DATA SOURCED
# (56.0) [EMLP] - DATA SOURCED
# (57.0) [COPX] - DATA SOURCED
# (58.0) [HAP] - DATA SOURCED
# (59.0) [PYZ] - DATA SOURCED
# (60.0) [RGI] - DATA SOURCED
# (61.0) [RTM] - DATA SOURCED
# (62.0) [PSCM] - DATA SOURCED
# (63.0) [PICK] - DATA SOURCED
# (64.0) [CRAK] - DATA SOURCED
# (65.0) [IYM] - DATA SOURCED
# (66.0) [REMX] - DATA SOURCED
# (67.0) [FXU] - DATA SOURCED
# (68.0) [FMAT] - DATA SOURCED
# (70.0) [VEGI] - DATA SOURCED
# (71.0) [VAW] - DATA SOURCED
# (72.0) [FTRI] - DATA SOURCED
# (73.0) [PSCI] - DATA SOURCED
# (74.0) [UPW] - DATA SOURCED
# (75.0) [RYU] - DATA SOURCED
# (76.0) [UTSL] - DATA SOURCED
# (77.0) [XLB] - DATA SOURCED
# (78.0) [FIW] - DATA SOURCED
# (79.0) [VIS] - DATA SOURCED
# (80.0) [FIDU] - DATA SOURCED
# (81.0) [PHO] - DATA SOURCED
# (82.0) [UTES] - DATA SOURCED
# (83.0) [ECLN] - DATA SOURCED
# (84.0) [FXR] - DATA SOURCED
# (85.0) [RLY] - DATA SOURCED
# (86.0) [DRLL] - DATA SOURCED
# (87.0) [FUTY] - DATA SOURCED
# (88.0) [VPU] - DATA SOURCED
# (89.0) [MOO] - DATA SOURCED
# (90.0) [FTAG] - DATA SOURCED
# (91.0) [XLU] - DATA SOURCED
# (92.0) [IDU] - DATA SOURCED
# (93.0) [EDOW] - DATA SOURCED
# (94.0) [PUI] - DATA SOURCED
# (95.0) [EXI] - DATA SOURCED
# (96.0) [IYJ] - DATA SOURCED
# (98.0) [MXI] - DATA SOURCED
# (100.0) [CGW] - DATA SOURCED
# (101.0) [UXI] - DATA SOURCED
# (104.0) [PSCU] - DATA SOURCED
# (105.0) [LIT] - DATA SOURCED
# (107.0) [PIO] - DATA SOURCED
# (108.0) [EIPX] - DATA SOURCED
# (110.0) [JXI] - DATA SOURCED
#      ticker       date                                              title  \
# 0      NRGU 2020-10-02  Bank of Montreal Announces the Reverse Split o...
# 1      NRGU 2020-05-20  Leveraged ETFs That Have Gained More Than 80% ...
# 2      NRGU 2020-05-11  6 Leveraged ETFs Up At Least 25% Last Week Zac...
# 3      NRGU 2020-01-08   Bet on Oil Surge With These Leveraged ETFs Zacks
# 4      NRGU 2019-10-14  5 Top-Performing Leveraged ETFs of Last Week Z...
# ...     ...        ...                                                ...
# 1064    FXZ 2017-12-12  Huntsman Repays Its Senior Term Loan Market Re...
# 1065    FXZ 2017-11-13  Huntsman to Pay 4Q17 Dividend in December Mark...
# 1066    FXZ 2017-09-25  Huntsmans 3Q17 Expectations amid Hurricane Har...
# 1067    FXZ 2017-09-18  How Attractive Is Eastman Chemicals Dividend Y...
# 1068    FXZ 2017-09-15  Huntsman Keeps Its Quarterly Dividend Stable M...
#
#                  source                                               link
# 0     finance.yahoo.com  https://finance.yahoo.com/news/bank-montreal-a...
# 1     finance.yahoo.com  https://finance.yahoo.com/news/leveraged-etfs-...
# 2     finance.yahoo.com  https://finance.yahoo.com/news/6-leveraged-etf...
# 3     finance.yahoo.com  https://finance.yahoo.com/news/bet-oil-surge-l...
# 4     finance.yahoo.com  https://finance.yahoo.com/news/5-top-performin...
# ...                 ...                                                ...
# 1064  marketrealist.com  http://marketrealist.com/2017/12/huntsman-repa...
# 1065  marketrealist.com  http://marketrealist.com/2017/11/huntsman-pay-...
# 1066  marketrealist.com  http://marketrealist.com/2017/09/huntsmans-3q1...
# 1067  marketrealist.com  http://marketrealist.com/2017/09/how-attractiv...
# 1068  marketrealist.com  http://marketrealist.com/2017/09/huntsman-keep...
#
# [1069 rows x 5 columns]

# %%
def sentiment_2(stocks, n=10):
    c = 0.0

    for stock in stocks:
        c += 1
        if exists(single_news / f"df_single_news_full_{stock}.pkl"):
            print(f"\n[ {int(c)} / {int(len(stocks))} ] - {stock} \n [X] - DONE - {stock}")

        else:
            print(f"\n[ {int(c)} / {int(len(stocks))} ] - {stock}")

            try:
                df = pd.DataFrame(pd.read_pickle(single_news / f"df_single_news_{stock}.pkl"))
                df.columns = [x.lower() for x in df.columns]
                df = df.sort_values('date', ascending=False).iloc[:n]
                list =[]                                                                         # creating an empty list

                for i in df.index:
                    dict = {}                                                                    # create empty dictionary to add articles
                    article = Article(df['link'][i], config=config)                              # providing the link

                    try:
                        article.download()                                                       # downloading the article 
                        article.parse()                                                          # parsing the article
                        article.nlp()                                                            # performing natural language processing
                    except Exception as e:                                                               # exception handling
                        print("Exception 2B:" + str(e))

                    dict['date']=df['date'][i]                                                   # storing results in dictionary from above
                    dict['source']=df['source'][i] 
                    dict['title']=article.title
                    dict['article']=article.text
                    dict['summary']=article.summary
                    dict['key_words']=article.keywords
                    dict['link']=df['link'][i]
                    list.append(dict)

                check_empty = not any(list)
                if check_empty == False:
                    try:
                        news_df=pd.DataFrame(list)                                               # creating dataframe
                        p1 = (single_news / f"df_single_news_full_{stock}.pkl")
                        news_df.to_pickle(p1)
                        print(f"[X] - DONE - {stock}")                                           # exception handling
                    except Exception as e:                                                               # exception handling
                        print("Exception 2C:" + str(e))
                        
            except Exception as e:                                                               # exception handling
                print("Exception 2A:" + str(e))

    return

# %%
sentiment_2(stocks_list)
# Out:
# [ 1 / 111 ] - NRGU
#  [X] - DONE - NRGU
#
# [ 2 / 111 ] - DIG
#  [X] - DONE - DIG
#
# [ 3 / 111 ] - ERX
#  [X] - DONE - ERX
#
# [ 4 / 111 ] - GUSH
#  [X] - DONE - GUSH
#
# [ 5 / 111 ] - PXE
#  [X] - DONE - PXE
#
# [ 6 / 111 ] - UCO
#  [X] - DONE - UCO
#
# [ 7 / 111 ] - FCG
#  [X] - DONE - FCG
#
# [ 8 / 111 ] - IEO
#  [X] - DONE - IEO
#
# [ 9 / 111 ] - FENY
#  [X] - DONE - FENY
#
# [ 10 / 111 ] - RYE
#  [X] - DONE - RYE
#
# [ 11 / 111 ] - XLE
#  [X] - DONE - XLE
#
# [ 12 / 111 ] - VDE
#  [X] - DONE - VDE
#
# [ 13 / 111 ] - IYE
#  [X] - DONE - IYE
#
# [ 14 / 111 ] - PXI
#  [X] - DONE - PXI
#
# [ 15 / 111 ] - FTXN
#  [X] - DONE - FTXN
#
# [ 16 / 111 ] - UGA
#  [X] - DONE - UGA
#
# [ 17 / 111 ] - XOP
#  [X] - DONE - XOP
#
# [ 18 / 111 ] - FXN
#  [X] - DONE - FXN
#
# [ 19 / 111 ] - PSCE
#  [X] - DONE - PSCE
#
# [ 20 / 111 ] - OIH
#  [X] - DONE - OIH
#
# [ 21 / 111 ] - FRAK
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_FRAK.pkl'
#
# [ 22 / 111 ] - BNO
#  [X] - DONE - BNO
#
# [ 23 / 111 ] - IEZ
#  [X] - DONE - IEZ
#
# [ 24 / 111 ] - IXC
#  [X] - DONE - IXC
#
# [ 25 / 111 ] - USO
#  [X] - DONE - USO
#
# [ 26 / 111 ] - FILL
#  [X] - DONE - FILL
#
# [ 27 / 111 ] - USL
#  [X] - DONE - USL
#
# [ 28 / 111 ] - DBE
#  [X] - DONE - DBE
#
# [ 29 / 111 ] - XME
#  [X] - DONE - XME
#
# [ 30 / 111 ] - AMZA
#  [X] - DONE - AMZA
#
# [ 31 / 111 ] - IGE
#  [X] - DONE - IGE
#
# [ 32 / 111 ] - XES
#  [X] - DONE - XES
#
# [ 33 / 111 ] - PXJ
#  [X] - DONE - PXJ
#
# [ 34 / 111 ] - NANR
#  [X] - DONE - NANR
#
# [ 35 / 111 ] - URNM
#  [X] - DONE - URNM
#
# [ 36 / 111 ] - MLPA
#  [X] - DONE - MLPA
#
# [ 37 / 111 ] - AMLP
#  [X] - DONE - AMLP
#
# [ 38 / 111 ] - IMLP
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_IMLP.pkl'
#
# [ 39 / 111 ] - DBC
#  [X] - DONE - DBC
#
# [ 40 / 111 ] - DBO
#  [X] - DONE - DBO
#
# [ 41 / 111 ] - MLPX
#  [X] - DONE - MLPX
#
# [ 42 / 111 ] - SLX
#  [X] - DONE - SLX
#
# [ 43 / 111 ] - UNL
#  [X] - DONE - UNL
#
# [ 44 / 111 ] - USAI
#  [X] - DONE - USAI
#
# [ 45 / 111 ] - EINC
#  [X] - DONE - EINC
#
# [ 46 / 111 ] - ENFR
#  [X] - DONE - ENFR
#
# [ 47 / 111 ] - FXZ
#  [X] - DONE - FXZ
#
# [ 48 / 111 ] - URA
#  [X] - DONE - URA
#
# [ 49 / 111 ] - TPYP
#  [X] - DONE - TPYP
#
# [ 50 / 111 ] - UMI
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_UMI.pkl'
#
# [ 51 / 111 ] - GRES
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_GRES.pkl'
#
# [ 52 / 111 ] - GUNR
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_GUNR.pkl'
#
# [ 53 / 111 ] - GNR
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_GNR.pkl'
#
# [ 54 / 111 ] - DUSL
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_DUSL.pkl'
#
# [ 55 / 111 ] - FUE
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_FUE.pkl'
#
# [ 56 / 111 ] - EMLP
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_EMLP.pkl'
#
# [ 57 / 111 ] - COPX
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_COPX.pkl'
#
# [ 58 / 111 ] - HAP
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_HAP.pkl'
#
# [ 59 / 111 ] - PYZ
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_PYZ.pkl'
#
# [ 60 / 111 ] - RGI
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_RGI.pkl'
#
# [ 61 / 111 ] - RTM
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_RTM.pkl'
#
# [ 62 / 111 ] - PSCM
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_PSCM.pkl'
#
# [ 63 / 111 ] - PICK
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_PICK.pkl'
#
# [ 64 / 111 ] - CRAK
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_CRAK.pkl'
#
# [ 65 / 111 ] - IYM
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_IYM.pkl'
#
# [ 66 / 111 ] - REMX
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_REMX.pkl'
#
# [ 67 / 111 ] - FXU
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_FXU.pkl'
#
# [ 68 / 111 ] - FMAT
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_FMAT.pkl'
#
# [ 69 / 111 ] - IWTR
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_IWTR.pkl'
#
# [ 70 / 111 ] - VEGI
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_VEGI.pkl'
#
# [ 71 / 111 ] - VAW
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_VAW.pkl'
#
# [ 72 / 111 ] - FTRI
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_FTRI.pkl'
#
# [ 73 / 111 ] - PSCI
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_PSCI.pkl'
#
# [ 74 / 111 ] - UPW
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_UPW.pkl'
#
# [ 75 / 111 ] - RYU
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_RYU.pkl'
#
# [ 76 / 111 ] - UTSL
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_UTSL.pkl'
#
# [ 77 / 111 ] - XLB
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_XLB.pkl'
#
# [ 78 / 111 ] - FIW
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_FIW.pkl'
#
# [ 79 / 111 ] - VIS
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_VIS.pkl'
#
# [ 80 / 111 ] - FIDU
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_FIDU.pkl'
#
# [ 81 / 111 ] - PHO
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_PHO.pkl'
#
# [ 82 / 111 ] - UTES
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_UTES.pkl'
#
# [ 83 / 111 ] - ECLN
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_ECLN.pkl'
#
# [ 84 / 111 ] - FXR
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_FXR.pkl'
#
# [ 85 / 111 ] - RLY
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_RLY.pkl'
#
# [ 86 / 111 ] - DRLL
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_DRLL.pkl'
#
# [ 87 / 111 ] - FUTY
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_FUTY.pkl'
#
# [ 88 / 111 ] - VPU
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_VPU.pkl'
#
# [ 89 / 111 ] - MOO
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_MOO.pkl'
#
# [ 90 / 111 ] - FTAG
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_FTAG.pkl'
#
# [ 91 / 111 ] - XLU
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_XLU.pkl'
#
# [ 92 / 111 ] - IDU
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_IDU.pkl'
#
# [ 93 / 111 ] - EDOW
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_EDOW.pkl'
#
# [ 94 / 111 ] - PUI
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_PUI.pkl'
#
# [ 95 / 111 ] - EXI
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_EXI.pkl'
#
# [ 96 / 111 ] - IYJ
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_IYJ.pkl'
#
# [ 97 / 111 ] - FGLD
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_FGLD.pkl'
#
# [ 98 / 111 ] - MXI
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_MXI.pkl'
#
# [ 99 / 111 ] - JHMU
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_JHMU.pkl'
#
# [ 100 / 111 ] - CGW
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_CGW.pkl'
#
# [ 101 / 111 ] - UXI
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_UXI.pkl'
#
# [ 102 / 111 ] - ION
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_ION.pkl'
#
# [ 103 / 111 ] - NDIV
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_NDIV.pkl'
#
# [ 104 / 111 ] - PSCU
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_PSCU.pkl'
#
# [ 105 / 111 ] - LIT
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_LIT.pkl'
#
# [ 106 / 111 ] - JZRO
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_JZRO.pkl'
#
# [ 107 / 111 ] - PIO
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_PIO.pkl'
#
# [ 108 / 111 ] - EIPX
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_EIPX.pkl'
#
# [ 109 / 111 ] - JHMI
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_JHMI.pkl'
#
# [ 110 / 111 ] - JXI
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_JXI.pkl'
#
# [ 111 / 111 ] - EBLU
# Exception 2A:[Errno 2] No such file or directory: '/home/gdp/hot_box/etfs/data/sentiment/single_news/2023/2023-02/2023-02-01/df_single_news_EBLU.pkl'

# %%
def sentiment_3(newS, stocks, a_or_b):
    for stock in stocks:
        try:
            parsed_news=[]
            if a_or_b == 'a':
                (
                    dates, sources, titles, links
                ) = (
                    newS['date'], newS['source'], newS['title'], newS['link']
                )
                
                for r in range(len(newS)):
                    parsed_news.append([stock, dates.iloc[r], sources.iloc[r], titles.iloc[r], links.iloc[r]])                

            elif a_or_b == 'b':
                (
                    dates, sources, titles, links, articles, summarys, key_words
                ) = (
                    newS['date'], newS['source'], newS['title'], newS['link'], newS['article'], newS['summary'], newS['key_words']
                )

                for r in range(len(newS)):
                    parsed_news.append([stock, dates.iloc[r], sources.iloc[r], titles.iloc[r], links.iloc[r], articles.iloc[r], summarys.iloc[r], key_words.iloc[r]])

        except Exception:
            print(f"BAD TICKER - 3A - {stock}")            
            return


        # Sentiment Analysis
        analyzer = SentimentIntensityAnalyzer()
        try:          
            if a_or_b == 'a':
                cols_lst = ["ticker", "date", 'source', "title", "link"]
                news = pd.DataFrame(parsed_news, columns=cols_lst).dropna()  
                scores = news["title"].apply(analyzer.polarity_scores).tolist()
                df_scores = pd.DataFrame(scores)
                news = news.join(df_scores, rsuffix="_right")            

            elif a_or_b == 'b':
                cols_lst = ['ticker', 'date', 'source', 'title', 'link', 'article', 'summary', 'key_words']
                news = pd.DataFrame(parsed_news, columns=cols_lst).dropna()  
                scores = news["summary"].apply(analyzer.polarity_scores).tolist()
                df_scores = pd.DataFrame(scores)
                news = news.join(df_scores, rsuffix="_right")  

        except Exception:
            print(f"BAD TICKER - 3B - {stock}")           
            return


        # View Data
        try:
            news["date"] = pd.to_datetime(news['date'])
            unique_ticker = news["ticker"].unique().tolist()
            news_dict = {name: news.loc[news["ticker"] == name] for name in unique_ticker}
            values = []

        except Exception:
            print(f"BAD TICKER - 3C - {stock}")
            return

    for stock in stocks:
        try:
            dataframe = news_dict[stock]
            dataframe = dataframe.set_index("ticker")
            mean = round(dataframe["compound"].mean() * 100, 0)
            values.append(mean)

        except Exception:
            print(f"BAD TICKER - 3D - {stock}")
            return

    try:
        df = pd.DataFrame(stocks, columns=["ticker"])
        df["sentiment_score"] = values
        return df  
    except Exception:
        print(f"BAD TICKER - 3E - {stock}")
        return



def sentiment_4(stocks, a_or_b):
    df = pd.DataFrame()
    symbols = []
    sentiments = []
    bad_stocks = []
    for stock in stocks:
        try:           
            if a_or_b == 'a':
                newS = pd.read_pickle(single_news / f"df_single_news_{stock}.pkl")

            elif a_or_b == 'b':
                newS = pd.read_pickle(single_news / f"df_single_news_full_{stock}.pkl")
            
            fd = pd.DataFrame(sentiment_3(newS, [stock], a_or_b))
            symbols.append(fd["ticker"].loc[0])
            sentiments.append(fd["sentiment_score"].loc[0])
            fd.to_pickle(sentiment / f"{stock}_sentiment.pkl")

        except Exception:
            print(f"BAD TICKER - 4 - {stock}")
            bad_stocks.append(stock)
            
    df["ticker"] = symbols
    df["sentiment_score"] = sentiments
    return df, bad_stocks



def sentiment_5(main_ticker_list, a_or_b):     
    df_final, bad_stocks = sentiment_4(main_ticker_list, a_or_b)
    print(df_final.shape)

    df_final = pd.DataFrame(df_final.copy()).sort_values('sentiment_score', ascending=False).sort_values('sentiment_score', ascending=False)
    df_final.to_pickle(saveRec / "recommender_03_return_dataFrame.pkl")

    print(f"[3] Sentiment Analysis - Successful Securities = [{len(df_final['ticker'])}]]")
    print(df_final.shape)
    return df_final, bad_stocks

# %%
data_3, bad_stocks_list = sentiment_5(stocks_list, a_or_b='b')

data_3
# Out:
# BAD TICKER - 4 - FRAK
# BAD TICKER - 4 - IMLP
# BAD TICKER - 4 - UMI
# BAD TICKER - 4 - GRES
# BAD TICKER - 4 - GUNR
# BAD TICKER - 4 - GNR
# BAD TICKER - 4 - DUSL
# BAD TICKER - 4 - FUE
# BAD TICKER - 4 - EMLP
# %%
data_3 = data_3.sort_values('ticker')
data_4 = pd.DataFrame(data_2[data_2['ticker'].isin(list(data_3['ticker']))]).sort_values('ticker')
data_4 = data_4.merge(data_3, on='ticker')
data_4
# Out:
#    ticker  rs_rating  returns_multiple  current_price  sma_50  sma_150  \
# 0    AMLP      76.73              1.42          40.78   39.12    38.82
# 1    AMZA      81.45              1.59          33.83   32.30    31.18
# 2     BNO      87.11              1.72          26.99   27.39    29.23
# 3     DBC      76.73              1.42          24.17   24.52    25.13
# 4     DBE      82.70              1.60          21.03   22.33    23.94
# 5     DBO      75.47              1.41          14.63   14.96    16.19
# 6     DIG      99.37              3.85          40.59   43.05    38.93
# 7    EINC      72.01              1.35          63.33   62.90    61.99
# 8    ENFR      72.01              1.35          22.24   21.77    21.59
# 9     ERX      98.74              3.71          63.61   67.10    60.17
# 10    FCG      95.91              2.17          24.01   25.05    25.03
# 11   FENY      94.97              2.02          23.49   24.00    22.54
# 12   FILL      84.28              1.64          23.74   24.50    23.51
# 13   FTXN      91.19              1.95          27.69   28.30    27.26
# 14    FXN      89.31              1.80          16.69   17.48    17.12
# 15    FXZ      70.75              1.34          71.62   64.60    60.52
# 16   GUSH      98.11              2.72         141.91  153.02   156.32
# 17    IEO      95.91              2.17          90.25   94.50    91.34
# 18    IEZ      85.85              1.69          21.69   21.12    18.31
# 19    IGE      81.45              1.59          41.21   41.37    39.32
# 20    IXC      85.85              1.69          38.60   39.46    37.44
# 21    IYE      92.45              1.97          45.59   46.88    44.30
# 22   MLPA      77.99              1.43          43.66   42.08    41.38
# 23   MLPX      74.84              1.40          42.32   41.66    41.05
# 24   NANR      79.25              1.53          55.98   55.94    52.64
# 25   NRGU     100.00              5.88         442.90  508.01   465.73
# 26    OIH      88.05              1.73         312.94  304.68   265.81
# 27   PSCE      88.68              1.78          10.45   10.25     9.85
# 28    PXE      97.48              2.34          28.97   30.30    29.99
# 29    PXI      91.82              1.96          43.24   44.45    43.57
# 30    PXJ      79.87              1.56           5.34    5.11     4.47
# 31    RYE      94.03              2.01          71.65   73.60    69.62
# 32    SLX      74.21              1.39          67.67   62.13    55.77
# 33   TPYP      69.81              1.33          25.61   25.36    25.25
# 34    UCO      96.86              2.24          27.19   28.56    31.79
# 35    UGA      90.57              1.93          58.87   56.99    58.30
# 36    UNL      73.58              1.38          12.70   18.03    21.36
# 37    URA      70.75              1.34          23.07   20.90    20.76
# 38   URNM      78.62              1.51          37.28   33.05    33.42
# 39   USAI      72.96              1.36          27.70   27.38    27.36
# 40    USL      83.65              1.63          33.82   34.42    35.67
# 41    USO      84.91              1.65          66.50   67.81    71.17
# 42    VDE      93.08              2.00         119.46  122.21   115.19
# 43    XES      80.50              1.57          84.23   79.35    69.23
# 44    XLE      94.03              2.01          85.99   87.99    82.33
# 45    XME      82.70              1.60          58.17   53.06    49.19
# 46    XOP      89.94              1.89         135.14  139.27   138.18
#
#     sma_200  sma_200_20  low_52_week  high_52_week  sentiment_score
# 0     38.70       38.55        32.25         42.47             38.0
# 1     30.94       30.68        24.40         34.44             74.0
# 2     30.06       30.34        22.78         36.84            -59.0
# 3     25.94       26.15        21.63         30.64             54.0
# 4     24.72       24.91        18.27         30.51             44.0
# 5     16.87       17.13        14.00         21.12             10.0
# 6     38.75       38.03        21.66         50.45            -13.0
# 7     62.36       62.48        53.82         69.56             47.0
# 8     21.76       21.83        18.96         24.52             39.0
# 9     60.38       59.26        34.20         80.27             58.0
# 10    25.22       25.24        17.12         31.07             61.0
# 11    22.41       22.12        16.16         25.98             77.0
# 12    23.53       23.37        18.77         26.88             32.0
# 13    27.28       27.12        20.04         31.87             74.0
# 14    16.91       16.79        12.03         19.47             32.0
# 15    62.20       62.57        50.60         75.76             63.0
# 16   162.11      164.31        84.50        257.76             53.0
# 17    90.86       89.97        63.44        106.36             73.0
# 18    18.41       18.14        13.47         23.40             66.0
# 19    39.63       39.51        32.16         45.70             41.0
# 20    37.49       37.18        29.49         42.98             46.0
# 21    43.90       43.35        31.69         50.75             79.0
# 22    41.15       40.93        34.80         44.22             57.0
# 23    41.27       41.36        35.81         45.94              8.0
# 24    53.54       53.71        44.03         61.96             25.0
# 25   478.63      470.57       198.58        797.00             44.0
# 26   267.18      264.00       195.77        336.30             56.0
# 27     9.95        9.94         6.87         12.55             50.0
# 28    30.05       29.87        19.97         36.69             78.0
# 29    43.81       43.73        30.59         53.05             92.0
# 30     4.45        4.39         3.25          5.61             60.0
# 31    69.84       69.23        50.72         82.02             10.0
# 32    56.65       56.91        46.17         70.43             49.0
# 33    25.50       25.61        22.09         28.55             32.0
# 34    35.09       36.18        24.26         55.69            -70.0
# 35    60.96       60.62        43.67         80.29             57.0
# 36    22.01       22.49        12.21         29.37             87.0
# 37    20.97       21.37        17.65         28.49             58.0
# 38    33.49       34.18        27.00         47.42             63.0
# 39    27.60       27.72        23.45         31.33             74.0
# 40    36.94       37.26        30.05         45.45             12.0
# 41    73.95       74.68        58.81         92.20             21.0
# 42   114.55      113.14        82.67        132.63             48.0
# 43    69.72       68.92        49.99         88.32             51.0
# 44    81.96       80.85        59.84         94.71             17.0
# 45    50.07       50.68        39.83         66.63             55.0
# 46   138.92      138.75        94.85        170.62             56.0

# %%
def create_new_cols(df):
    df["my_score"] = (((df["rs_rating"]) + (df["sentiment_score"])) / 2)
    return df   



def company_longName(ticker):
    try:
        d = Ticker(ticker).quote_type
        return list(d.values())[0]["longName"]
    except Exception as e:
        return ticker

# %%
data_5 = create_new_cols(data_4).round(2).sort_values('my_score', ascending=False)

# %%
data_5_tickers = list(data_5['ticker'])
data_5_names = []

for ticker in data_5_tickers:
    data_5_names.append(company_longName(ticker))

data_5['name'] = data_5_names
data_5 = data_5.set_index('name')
data_5 = data_5[
    [
        'ticker', 'my_score', 'sentiment_score', 'rs_rating', 'returns_multiple', 'current_price', 'sma_50', 'sma_150', 'sma_200', 'sma_200_20', 'low_52_week', 'high_52_week', 
    ]
]

# %%
# data_5 = data_5[data_5['sentiment_score'] > 0.0]

# %%
data_5 = data_5[data_5['ticker'] != 'URA']
data_5 = data_5[data_5['ticker'] != 'SLX']

# %%
data_5.to_pickle(saveRec / "recommender_05_return_dataFrame.pkl")
data_5.to_csv(saveRec / "recommender_05_return_dataFrame.csv")
data_5
# Out:
#                                                    ticker  my_score  \
# name
# Invesco DWA Energy Momentum ETF                       PXI     91.91
# Invesco Dynamic Energy Exploration & Production...    PXE     87.74
# Fidelity MSCI Energy Index ETF                       FENY     85.98
# iShares U.S. Energy ETF                               IYE     85.72
# iShares U.S. Oil & Gas Exploration & Production...    IEO     84.46
# First Trust Nasdaq Oil & Gas ETF                     FTXN     82.60
# United States 12 Month Natural Gas Fund, LP           UNL     80.29
# First Trust Natural Gas ETF                           FCG     78.46
# Direxion Daily Energy Bull 2X Shares                  ERX     78.37
# InfraCap MLP ETF                                     AMZA     77.72
# iShares U.S. Oil Equipment & Services ETF             IEZ     75.92
# Direxion Daily S&P Oil & Gas Exp. & Prod. Bull ...   GUSH     75.56
# United States Gasoline Fund, LP                       UGA     73.78
# Pacer American Energy Independence ETF               USAI     73.48
# SPDR S&P Oil & Gas Exploration & Production ETF       XOP     72.97
# VanEck Oil Services ETF                               OIH     72.03
# MicroSectors U.S. Big Oil Index 3X Leveraged ETNs    NRGU     72.00
# Sprott Uranium Miners ETF                            URNM     70.81
# Vanguard Energy Index Fund                            VDE     70.54
# Invesco Dynamic Oil & Gas Services ETF                PXJ     69.94
# Invesco S&P SmallCap Energy ETF                      PSCE     69.34
# SPDR S&P Metals and Mining ETF                        XME     68.85
# Global X MLP ETF                                     MLPA     67.50
# First Trust Materials AlphaDEX Fund                   FXZ     66.88
# iShares Global Energy ETF                             IXC     65.92
# SPDR S&P Oil & Gas Equipment & Services ETF           XES     65.75
# Invesco DB Commodity Index Tracking Fund              DBC     65.37
# Invesco DB Energy Fund                                DBE     63.35
# iShares North American Natural Resources ETF          IGE     61.22
# First Trust Energy AlphaDEX Fund                      FXN     60.66
# VanEck Energy Income ETF                             EINC     59.50
# iShares MSCI Global Energy Producers ETF             FILL     58.14
# Alerian MLP ETF                                      AMLP     57.36
# Energy Select Sector SPDR Fund                        XLE     55.52
# Alerian Energy Infrastructure ETF                    ENFR     55.50
# United States Oil Fund, LP                            USO     52.96
# SPDR S&P North American Natural Resources ETF        NANR     52.12
# Invesco S&P 500 Equal Weight Energy ETF               RYE     52.02
# Tortoise North American Pipeline Fund                TPYP     50.90
# United States 12 Month Oil Fund, LP                   USL     47.82
# ProShares Ultra Oil & Gas                             DIG     43.18
# Invesco DB Oil Fund                                   DBO     42.74
# Global X MLP & Energy Infrastructure ETF             MLPX     41.42
# United States Brent Oil Fund, LP                      BNO     14.06
# ProShares Ultra Bloomberg Crude Oil                   UCO     13.43
#
#                                                     sentiment_score  \
# name
# Invesco DWA Energy Momentum ETF                                92.0
# Invesco Dynamic Energy Exploration & Production...             78.0
# Fidelity MSCI Energy Index ETF                                 77.0
# iShares U.S. Energy ETF                                        79.0
# iShares U.S. Oil & Gas Exploration & Production...             73.0
# First Trust Nasdaq Oil & Gas ETF                               74.0
# United States 12 Month Natural Gas Fund, LP                    87.0
# First Trust Natural Gas ETF                                    61.0
# Direxion Daily Energy Bull 2X Shares                           58.0
# InfraCap MLP ETF                                               74.0
# iShares U.S. Oil Equipment & Services ETF                      66.0
# Direxion Daily S&P Oil & Gas Exp. & Prod. Bull ...             53.0
# United States Gasoline Fund, LP                                57.0
# Pacer American Energy Independence ETF                         74.0
# SPDR S&P Oil & Gas Exploration & Production ETF                56.0
# VanEck Oil Services ETF                                        56.0
# MicroSectors U.S. Big Oil Index 3X Leveraged ETN
# Invesco DB Oil Fund                                      17.13        14.00
# Global X MLP & Energy Infrastructure ETF                 41.36        35.81
# United States Brent Oil Fund, LP                         30.34        22.78
# ProShares Ultra Bloomberg Crude Oil                      36.18        24.26
#
#                                                     high_52_week
# name
# Invesco DWA Energy Momentum ETF                            53.05
# Invesco Dynamic Energy Exploration & Production...         36.69
# Fidelity MSCI Energy Index ETF                             25.98
# iShares U.S. Energy ETF                                    50.75
# iShares U.S. Oil & Gas Exploration & Production...        106.36
# First Trust Nasdaq Oil & Gas ETF                           31.87
# United States 12 Month Natural Gas Fund, LP                29.37
# First Trust Natural Gas ETF                                31.07
# Direxion Daily Energy Bull 2X Shares                       80.27
# InfraCap MLP ETF                                           34.44
# iShares U.S. Oil Equipment & Services ETF                  23.40
# Direxion Daily S&P Oil & Gas Exp. & Prod. Bull ...        257.76
# United States Gasoline Fund, LP                            80.29
# Pacer American Energy Independence ETF                     31.33
# SPDR S&P Oil & Gas Exploration & Production ETF           170.62
# VanEck Oil Services ETF                                   336.30
# MicroSectors U.S. Big Oil Index 3X Leveraged ETNs         797.00
# Sprott Uranium Miners ETF                                  47.42
# Vanguard Energy Index Fund                                132.63
# Invesco Dynamic Oil & Gas Services ETF                      5.61
# Invesco S&P SmallCap Energy ETF                            12.55
# SPDR S&P Metals and Mining ETF                             66.63
# Global X MLP ETF                                           44.22
# First Trust Materials AlphaDEX Fund                        75.76
# iShares Global Energy ETF                                  42.98
# SPDR S&P Oil & Gas Equipment & Services ETF                88.32
# Invesco DB Commodity Index Tracking Fund                   30.64
# Invesco DB Energy Fund                                     30.51
# iShares North American Natural Resources ETF               45.70
# First Trust Energy AlphaDEX Fund                           19.47
# VanEck Energy Income ETF                                   69.56
# iShares MSCI Global Energy Producers ETF                   26.88
# Alerian MLP ETF                                            42.47
# Energy Select Sector SPDR Fund                             94.71
# Alerian Energy Infrastructure ETF                          24.52
# United States Oil Fund, LP                                 92.20
# SPDR S&P North American Natural Resources ETF              61.96
# Invesco S&P 500 Equal Weight Energy ETF                    82.02
# Tortoise North American Pipeline Fund                      28.55
# United States 12 Month Oil Fund, LP                        45.45
# ProShares Ultra Oil & Gas                                  50.45
# Invesco DB Oil Fund                                        21.12
# Global X MLP & Energy Infrastructure ETF                   45.94
# United States Brent Oil Fund, LP                           36.84
# ProShares Ultra Bloomberg Crude Oil                        55.69

# %%
data_5.columns
# Out:
# Index(['ticker', 'my_score', 'sentiment_score', 'rs_rating',
#        'returns_multiple', 'current_price', 'sma_50', 'sma_150', 'sma_200',
#        'sma_200_20', 'low_52_week', 'high_52_week'],
#       dtype='object')

# %%
for i in list(data_5['ticker']):
    print(i)
# Out:
# PXI
# PXE
# FENY
# IYE
# IEO
# FTXN
# UNL
# FCG
# ERX
# AMZA
# IEZ
# GUSH
# UGA
# USAI
# XOP
# OIH
# NRGU
# URNM
# VDE
# PXJ
# PSCE
# XME
# MLPA
# FXZ
# IXC
# XES
# DBC
# DBE
# IGE
# FXN
# EINC
# FILL
# AMLP
# XLE
# ENFR
# USO
# NANR
# RYE
# TPYP
# USL
# DIG
# DBO
# MLPX
# BNO
# UCO
